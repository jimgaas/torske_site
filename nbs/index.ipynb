# %%
#| hide
from torske_site.core import *

# %% [markdown]
# # torske_site
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install torske_site in Development mode

# %% [markdown]
# ```sh
# # make sure torske_site package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to torske_site
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/jimgaas/torske_site.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c jimgaas torske_site
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install torske_site
# ```
#
#
# [repo]: https://github.com/jimgaas/torske_site
# [docs]: https://jimgaas.github.io/torske_site/
# [pypi]: https://pypi.org/project/torske_site/
# [conda]: https://anaconda.org/jimgaas/torske_site

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/jimgaas/torske_site
# [docs]: https://jimgaas.github.io/torske_site/
# [pypi]: https://pypi.org/project/torske_site/
# [conda]: https://anaconda.org/jimgaas/torske_site

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
